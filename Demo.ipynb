# %% [markdown]
# # Importing Libraries

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# # Setup Spark

# %% [markdown]
# ## Paths

# %%
mysql_url = "jdbc:mysql://localhost:3306/my_database"
mongo_url=""

# %% [markdown]
# ## Config

# %%
mysql_config = {
    "user": "root",
    "password": "123@123",
    "driver": "com.mysql.cj.jdbc.Driver",
}

# %% [markdown]
# ## Connect

# %%
spark_mysql = (
    SparkSession.builder.appName("SparkByExamplses.com")
    .config("spark.jars", "libs/mysql-connector-java-8.0.13.jar")
    .getOrCreate()
)
# Out:
# 24/07/16 23:47:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# # Run Demo

# %% [markdown]
# ## DML

# %%
df = spark_mysql.read.jdbc(url=mysql_url, table="my_table", properties=mysql_config)

# %% [markdown]
# ## DDL

# %% [markdown]
# ## Security

# %% [markdown]
# ## Import/ Export (Backup/ Restore)

# %% [markdown]
# ## Logger
